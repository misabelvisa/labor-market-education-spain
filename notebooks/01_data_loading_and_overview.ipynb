# %%
# Proyecto: Evolución del mercado laboral y educación en España
# Autor: Maria Isabel Villar
# Fecha: Enero 2026

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("librerías listas")
# Out:
# librerias listas
